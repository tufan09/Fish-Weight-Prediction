# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fish=pd.read_csv("Fish.csv")

# %%
fish.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
fish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
fish.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
sns.boxplot(x=fish['Height'])

# %%
sns.boxplot(x=fish['Weight'])

# %%
out_liers=np.where(fish['Weight']>1500)

# %%
fish.drop(out_liers[0],inplace=True)

# %%
sns.boxplot(x=fish['Width'])

# %%
sns.boxplot(x=fish['Length1'])

# %%
out_liers1=np.where(fish['Length1']>50)

# %%
fish.drop(out_liers1[0],inplace=True)

# %%
sns.boxplot(x=fish['Length2'])

# %%
sns.boxplot(x=fish['Length3'])

# %%
fish.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  155 non-null    object
#  1   Weight   155 non-null    float64
#  2   Length1  155 non-null    float64
#  3   Length2  155 non-null    float64
#  4   Length3  155 non-null    float64
#  5   Height   155 non-null    float64
#  6   Width    155 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 9.7+ KB

# %%
sns.countplot(data=fish, x='Species')

# %%
corr=fish.corr()

# %%
plt.subplots(figsize=(5,5))
sns.heatmap(data=corr, annot=True, linewidths=0.5)

# %%
fish.drop(labels=['Length1','Length2','Species'], axis=1, inplace=True)

# %%
fish.head()
# Out:
#    Weight  Length3   Height   Width
# 0   242.0     30.0  11.5200  4.0200
# 1   290.0     31.2  12.4800  4.3056
# 2   340.0     31.1  12.3778  4.6961
# 3   363.0     33.5  12.7300  4.4555
# 4   430.0     34.0  12.4440  5.1340

# %%
from sklearn.model_selection import train_test_split

# %%
train,test=train_test_split(fish, test_size=0.2, random_state=42)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124 entries, 96 to 102
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Weight   124 non-null    float64
#  1   Length3  124 non-null    float64
#  2   Height   124 non-null    float64
#  3   Width    124 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 81 to 126
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Weight   31 non-null     float64
#  1   Length3  31 non-null     float64
#  2   Height   31 non-null     float64
#  3   Width    31 non-null     float64
# dtypes: float64(4)
# memory usage: 1.2 KB

# %%
train.head()
# Out:
#      Weight  Length3   Height   Width
# 96    225.0     25.5   7.2930  3.7230
# 122   820.0     42.5  11.1350  6.6300
# 82    110.0     22.5   5.6925  3.5550
# 109   514.0     34.0  10.0300  6.0180
# 65    150.0     22.4   8.8928  3.2928

# %%
test.head()
# Out:
#      Weight  Length3   Height   Width
# 81     85.0     21.0   5.0820  2.7720
# 146     7.5     11.6   1.9720  1.1600
# 31    955.0     44.0  18.0840  6.2920
# 29   1000.0     42.6  18.9570  6.6030
# 118   820.0     41.3  12.4313  7.3514

# %%
y=train['Weight']

# %%
y.head()
# Out:
# 96     225.0
# 122    820.0
# 82     110.0
# 109    514.0
# 65     150.0
# Name: Weight, dtype: float64

# %%
train.head()
# Out:
#      Weight  Length3   Height   Width
# 96    225.0     25.5   7.2930  3.7230
# 122   820.0     42.5  11.1350  6.6300
# 82    110.0     22.5   5.6925  3.5550
# 109   514.0     34.0  10.0300  6.0180
# 65    150.0     22.4   8.8928  3.2928

# %%
train.drop(labels='Weight', axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
train.head()
# Out:
#      Length3   Height   Width
# 96      25.5   7.2930  3.7230
# 122     42.5  11.1350  6.6300
# 82      22.5   5.6925  3.5550
# 109     34.0  10.0300  6.0180
# 65      22.4   8.8928  3.2928

# %%
y_test=test['Weight']

# %%
y_test.head()
# Out:
# 81       85.0
# 146       7.5
# 31      955.0
# 29     1000.0
# 118     820.0
# Name: Weight, dtype: float64

# %%
test.drop(labels='Weight', axis=1, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
test.head()
# Out:
#      Length3   Height   Width
# 81      21.0   5.0820  2.7720
# 146     11.6   1.9720  1.1600
# 31      44.0  18.0840  6.2920
# 29      42.6  18.9570  6.6030
# 118     41.3  12.4313  7.3514

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
lin_reg=LinearRegression()

# %%
lin_reg.fit(train,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict=lin_reg.predict(test)

# %%
y_predict[0:5]
# Out:
# array([  85.51641085, -191.06712742,  764.36830548,  786.06688814,
#         792.17621862])

# %%
r2_score(y_test, y_predict)
# Out:
# 0.90690423537428
